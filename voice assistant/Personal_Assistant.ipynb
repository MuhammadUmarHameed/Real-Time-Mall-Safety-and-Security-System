# %%
import ctypes
import json
import subprocess
import time
from urllib.request import urlopen
import pyttsx3
import os
import datetime
import requests
import wikipedia
import webbrowser
import speech_recognition as sr 
import random

count = 0
new_rate = 150
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)
engine.setProperty('rate', new_rate)

def speak(audio):
    # this function is for computer speaking
    engine.say(audio)
    engine.runAndWait()

def greetings():
    hour = int(datetime.datetime.now().hour)
    if hour < 12:
        speak("Hello, Good Morning")
    elif 12 <= hour < 17:
        speak("Hello, Good Afternoon")
    elif 17 <= hour < 22:
        speak("Hello, Good Evening")
    else:
        speak("Hello, Good Night")
    speak("I am Sera. How can I help you.")

def take_command():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.adjust_for_ambient_noise(source, duration=1)
        audio = r.listen(source)
    
    try:
        print("Recognizing...")
        main_query = r.recognize_google(audio, language='en-uk')
        print(f"User said: {main_query}\n")
    except Exception as e:
        print("Say that again please...")
        return "none"
    return main_query.lower()

if __name__ == '__main__':
    greetings()
    while True:
        if count > 0:
            speak("Anything else?")

        main_query = take_command()
        print("User said:", main_query)

        if 'wikipedia' in main_query:
            speak("Searching in Wikipedia...")
            main_query = main_query.replace("wikipedia", "")
            results = wikipedia.summary(main_query, sentences=2)
            speak("According to Wikipedia")
            print(results)
            speak(results)
            count += 1

        elif 'facebook' in main_query:
            webbrowser.open('https://www.facebook.com')
            count += 1

        elif 'code' in main_query:
            code_path = "C:\\Users\\Admin\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe"
            os.startfile(code_path)
            count += 1

        elif 'time' in main_query:
            str_time = datetime.datetime.now().strftime('%H:%M:%S')
            speak(str_time)
            count += 1

        elif 'cafeteria' in main_query or 'canteen' in main_query or 'food court' in main_query:
            speak("It is on the fourth floor.")
            count += 1

        elif 'sana safinaz' in main_query:
            speak("It is on the third floor, shop number 3.")
            count += 1

        elif 'gul ahmed' in main_query:
            speak("It is on the third floor, shop number 1.")
            count += 1

        elif 'al karam' in main_query:
            speak("It is on the second floor, shop number 3.")
            count += 1

        elif 'jay dot' in main_query:
            speak("It is on the first floor, shop number 3.")
            count += 1

        elif 'washroom' in main_query or 'bathroom' in main_query:
            speak("Please turn left, then go straight.")
            count += 1

        elif 'emergency exit' in main_query:
            speak("Please turn right, then go straight, take left and there are stairs which lead you towards the emergency exit gate.")
            count += 1

        elif 'exit' in main_query:
            speak("Please turn left, then go straight, take right and there is the main exit gate.")
            count += 1

        elif 'fire' in main_query:
            speak("Please turn right, then go straight, take left and there are stairs which lead you towards the emergency exit gate.")
            count += 1

        elif 'none' in main_query:
            speak("Say that again please")
            count += 1
            print("Checking for 'thank you'...")
        
        
        elif 'thank you' in main_query or 'thankyou' in main_query:
            speak("It's my pleasure.")
            exit()

        elif 'thanks' in main_query or 'thank' in main_query:
            speak("It's my pleasure.")
            exit()
            
        elif 'none' in main_query or 'no' in main_query:
            speak("It's my pleasure.")
            exit()


        elif 'open youtube' in main_query:
            speak("Here you go to Youtube\n")
            webbrowser.open("youtube.com")

        elif 'open google' in main_query:
            speak("Here you go to Google\n")
            webbrowser.open("google.com")

        elif 'open stackoverflow' in main_query:
            speak("Here you go to Stack Over flow.Happy coding")
            webbrowser.open("stackoverflow.com")

        elif 'play music' in main_query or "play song" in main_query:
            speak("Here you go with music")
            # music_dir = "G:\\Song"
            music_dir = "C:\\Users\\GAURAV\\Music"
            songs = os.listdir(music_dir)
            print(songs)
            random = os.startfile(os.path.join(music_dir, songs[1]))

        elif 'the time' in main_query:
            strTime = datetime.datetime.now().strftime("% H:% M:% S")
            speak(f"Sir, the time is {strTime}")

        elif 'open chrome' in main_query:
            codePath = r"C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe"
            os.startfile(codePath)

        elif 'email to hassan' in main_query:
            try:
                speak("What should I say?")
                content = take_command()
                to = "Receiver email address"
                sendEmail(to, content)
                speak("Email has been sent !")
            except Exception as e:
                print(e)
                speak("I am not able to send this email")

        elif 'send a mail' in main_query:
            try:
                speak("What should I say?")
                content = take_command()
                speak("whom should i send")
                to = input()
                sendEmail(to, content)
                speak("Email has been sent !")
            except Exception as e:
                print(e)
                speak("I am not able to send this email")

        elif "change my name to" in main_query:
            main_query = main_query.replace("change my name to", "")
            assname = main_query

        elif "change name" in main_query:
            speak("What would you like to call me, Sir ")
            assname = take_command()
            speak("Thanks for naming me")

        elif "what's your name" in main_query or "What is your name" in main_query:
            speak("My friends call me")
            speak(assname)
            print("My friends call me", assname)

        elif "who made you" in main_query or "who created you" in main_query:
            speak("I have been created by Umar.")
            
        elif 'joke' in main_query:
            speak(pyjokes.get_joke())
            
        elif "calculate" in main_query:
            
            app_id = "Wolframalpha api id"
            client = wolframalpha.client(app_id)
            indx = main_query.lower().split().index('calculate')
            main_query = main_query.split()[indx + 1:]
            res = client.main_query(' '.join(main_query))
            answer = next(res.results).text
            print("The answer is " + answer)
            speak("The answer is " + answer)

        elif 'search' in main_query or 'play' in main_query:
            
            main_query = main_query.replace("search", "")
            main_query = main_query.replace("play", "")		
            webbrowser.open(main_query)

        elif "who i am" in main_query:
            speak("If you talk then definitely your human.")

        elif "why you came to world" in main_query:
            speak("Thanks to Gaurav. further It's a secret")

        elif 'is love' in main_query:
            speak("It is 7th sense that destroy all other senses")

        elif "who are you" in main_query:
            speak("I am your virtual assistant created by Gaurav")

        elif 'reason for you' in main_query:
            speak("I was created as a Minor project by Mister Gaurav ")

        elif 'change background' in main_query:
            ctypes.windll.user32.SystemParametersInfoW(20,
                                                    0,
                                                    "Location of wallpaper",
                                                    0)
            speak("Background changed successfully")
      
        elif 'lock window' in main_query:
                speak("locking the device")
                ctypes.windll.user32.LockWorkStation()

        elif 'shutdown system' in main_query:
                speak("Hold On a Sec ! Your system is on its way to shut down")
                subprocess.call('shutdown / p /f')
                
        elif 'empty recycle bin' in main_query:
            winshell.recycle_bin().empty(confirm = False, show_progress = False, sound = True)
            speak("Recycle Bin Recycled")

        elif "don't listen" in main_query or "stop listening" in main_query:
            speak("for how much time you want to stop sera from listening commands")
            a = int(take_command())
            time.sleep(a)
            print(a)

        elif "where is" in main_query:
            main_query = main_query.replace("where is", "")
            location = main_query
            speak("User asked to Locate")
            speak(location)
            webbrowser.open("https://www.google.nl / maps / place/" + location + "")

        elif "camera" in main_query or "take a photo" in main_query:
            ec.capture(0, "sera Camera ", "img.jpg")

        elif "restart" in main_query:
            subprocess.call(["shutdown", "/r"])
            
        elif "hibernate" in main_query or "sleep" in main_query:
            speak("Hibernating")
            subprocess.call("shutdown / h")

        elif "log off" in main_query or "sign out" in main_query:
            speak("Make sure all the application are closed before sign-out")
            time.sleep(5)
            subprocess.call(["shutdown", "/l"])

        elif "write a note" in main_query:
            speak("What should i write, sir")
            note = take_command()
            file = open('sera.txt', 'w')
            speak("Sir, Should i include date and time")
            snfm = take_command()
            if 'yes' in snfm or 'sure' in snfm:
                strTime = datetime.datetime.now().strftime("% H:% M:% S")
                file.write(strTime)
                file.write(" :- ")
                file.write(note)
            else:
                file.write(note)

        elif "show note" in main_query:
            speak("Showing Notes")
            file = open("sera.txt", "r")
            print(file.read())
            speak(file.read(6))

        elif "update assistant" in main_query:
            speak("After downloading file please replace this file with the downloaded one")
            url = '# url after uploading file'
            r = requests.get(url, stream = True)
            
            with open("Voice.py", "wb") as Pypdf:
                
                total_length = int(r.headers.get('content-length'))
                
                for ch in progress.bar(r.iter_content(chunk_size = 2391975),
                                    expected_size =(total_length / 1024) + 1):
                    if ch:
                        Pypdf.write(ch)
                    
        elif "sera" in main_query:
            
            wishMe()
            speak("sera 1 point o in your service Mister")
            speak(assname)

        elif "weather" in main_query:
            
            # Google Open weather website
            # to get API of Open weather
            api_key = "Api key"
            base_url = "http://api.openweathermap.org / data / 2.5 / weather?"
            speak(" City name ")
            print("City name : ")
            city_name = take_command()
            complete_url = base_url + "appid =" + api_key + "&q =" + city_name
            response = requests.get(complete_url)
            x = response.json()
            
            if x["cod"] != "404":
                y = x["main"]
                current_temperature = y["temp"]
                current_pressure = y["pressure"]
                current_humidiy = y["humidity"]
                z = x["weather"]
                weather_description = z[0]["description"]
                print(" Temperature (in kelvin unit) = " +str(current_temperature)+"\n atmospheric pressure (in hPa unit) ="+str(current_pressure) +"\n humidity (in percentage) = " +str(current_humidiy) +"\n description = " +str(weather_description))
            
            else:
                speak(" City Not Found ")
            


        elif "wikipedia" in main_query:
            webbrowser.open("wikipedia.com")

        elif "Good Morning" in main_query:
            speak("A warm" +main_query)
            speak("How are you Mister")
            speak(assname)

        # most asked question from google Assistant
        elif "will you be my gf" in main_query or "will you be my bf" in main_query:
            speak("I'm not sure about, may be you should give me some time")

        elif "how are you" in main_query:
            speak("I'm fine, glad you asked me that")

        elif "i love you" in main_query:
            speak("It's hard to understand")

        elif "what is" in main_query or "who is" in main_query:
            
            # Use the same API key
            # that we have generated earlier
            client = wolframalpha.Client("API_ID")
            res = client.main_query(main_query)
            
            try:
                print (next(res.results).text)
                speak (next(res.results).text)
            except StopIteration:
                print ("No results")
# Out:
# Listening...
# Recognizing...
# User said: no
#
# User said: no
# Listening...
# Recognizing...
